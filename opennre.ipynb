# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
import numpy as np
import os
import sys
from tqdm.notebook import tqdm

# %%
import torch

# %%
# !python sys.path.append('../code/OpenNRE')
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `python sys.path.append('../code/OpenNRE')'

# %%
# rubert 
# !python ../code/OpenNRE/example/train_supervised_bert.py \
    --pretrain_path DeepPavlov/rubert-base-cased-sentence \
    --ckpt rubert_ent_e5_s43_bio\
    --pooler entity \
    --metric macro_f1 \
    --train_fil new_results/NEREL_BIOv2.0_train.txt \
    --val_file new_results/NEREL_BIOv2.0_dev.txt \
    --test_file new_results/NEREL_BIOv2.0_test.txt \
    --rel2id_file new_results/rels_NEREL-BIO.txt \
    --batch_size 32 \
    --lr 3e-5 \
    --max_length 128 \
    --max_epoch 5 \
    --seed 43
# Out:
# 2023-04-17 04:04:27,031 - root - INFO - Arguments:
# 2023-04-17 04:04:27,031 - root - INFO -     pretrain_path: DeepPavlov/rubert-base-cased-sentence
# 2023-04-17 04:04:27,031 - root - INFO -     ckpt: rubert_ent_e5_s43_bio
# 2023-04-17 04:04:27,031 - root - INFO -     pooler: entity
# 2023-04-17 04:04:27,031 - root - INFO -     only_test: False
# 2023-04-17 04:04:27,031 - root - INFO -     mask_entity: False
# 2023-04-17 04:04:27,031 - root - INFO -     metric: macro_f1
# 2023-04-17 04:04:27,031 - root - INFO -     dataset: none
# 2023-04-17 04:04:27,032 - root - INFO -     train_file: new_results/NEREL_BIOv2.0_train.txt
# 2023-04-17 04:04:27,032 - root - INFO -     val_file: new_results/NEREL_BIOv2.0_dev.txt
# 2023-04-17 04:04:27,032 - root - INFO -     test_file: new_results/NEREL_BIOv2.0_test.txt
# 2023-04-17 04:04:27,032 - root - INFO -     rel2id_file: new_results/rels_NEREL-BIO.txt
# 2023-04-17 04:04:27,032 - root - INFO -     batch_size: 32
# ...

# %%
# multilingual
# !python ../code/OpenNRE/example/train_supervised_bert.py \
    --pretrain_path bert-base-multilingual-cased \
    --ckpt multilingual_e5_s43_bio\
    --pooler entity \
    --metric macro_f1 \
    --train_fil new_results/NEREL_BIOv2.0_train.txt \
    --val_file new_results/NEREL_BIOv2.0_dev.txt \
    --test_file new_results/NEREL_BIOv2.0_test.txt \
    --rel2id_file new_results/rels_NEREL-BIO.txt \
    --batch_size 32 \
    --lr 3e-5 \
    --max_length 128 \
    --max_epoch 5 \
    --seed 43
# Out:
# 2023-04-17 10:24:48,434 - root - INFO - Arguments:
# 2023-04-17 10:24:48,434 - root - INFO -     pretrain_path: bert-base-multilingual-cased
# 2023-04-17 10:24:48,434 - root - INFO -     ckpt: multilingual_e5_s43_bio
# 2023-04-17 10:24:48,434 - root - INFO -     pooler: entity
# 2023-04-17 10:24:48,434 - root - INFO -     only_test: False
# 2023-04-17 10:24:48,434 - root - INFO -     mask_entity: False
# 2023-04-17 10:24:48,434 - root - INFO -     metric: macro_f1
# 2023-04-17 10:24:48,434 - root - INFO -     dataset: none
# 2023-04-17 10:24:48,434 - root - INFO -     train_file: new_results/NEREL_BIOv2.0_train.txt
# 2023-04-17 10:24:48,434 - root - INFO -     val_file: new_results/NEREL_BIOv2.0_dev.txt
# 2023-04-17 10:24:48,434 - root - INFO -     test_file: new_results/NEREL_BIOv2.0_test.txt
# 2023-04-17 10:24:48,434 - root - INFO -     rel2id_file: new_results/rels_NEREL-BIO.txt
# 2023-04-17 10:24:48,434 - root - INFO -     batch_size: 32
# ...

# %%
# Clinical BERT
# !python ../code/OpenNRE/example/train_supervised_bert.py \
    --pretrain_path emilyalsentzer/Bio_ClinicalBERT \
    --ckpt clinical_e5_s43_bio\
    --pooler entity \
    --metric macro_f1 \
    --train_fil new_results/NEREL_BIOv2.0_train.txt \
    --val_file new_results/NEREL_BIOv2.0_dev.txt \
    --test_file new_results/NEREL_BIOv2.0_test.txt \
    --rel2id_file new_results/rels_NEREL-BIO.txt \
    --batch_size 32 \
    --lr 3e-5 \
    --max_length 128 \
    --max_epoch 5 \
    --seed 43
# Out:
# 2023-04-19 21:59:24,335 - root - INFO - Arguments:
# 2023-04-19 21:59:24,335 - root - INFO -     pretrain_path: emilyalsentzer/Bio_ClinicalBERT
# 2023-04-19 21:59:24,335 - root - INFO -     initial_ckpt: None
# 2023-04-19 21:59:24,335 - root - INFO -     ckpt: clinical_e5_s43_bio
# 2023-04-19 21:59:24,335 - root - INFO -     pooler: entity
# 2023-04-19 21:59:24,335 - root - INFO -     only_test: False
# 2023-04-19 21:59:24,335 - root - INFO -     mask_entity: False
# 2023-04-19 21:59:24,335 - root - INFO -     metric: macro_f1
# 2023-04-19 21:59:24,335 - root - INFO -     dataset: none
# 2023-04-19 21:59:24,335 - root - INFO -     train_file: new_results/NEREL_BIOv2.0_train.txt
# 2023-04-19 21:59:24,335 - root - INFO -     val_file: new_results/NEREL_BIOv2.0_dev.txt
# 2023-04-19 21:59:24,335 - root - INFO -     test_file: new_results/NEREL_BIOv2.0_test.txt
# 2023-04-19 21:59:24,335 - root - INFO -     rel2id_file: new_results/rels_NEREL-BIO.txt
# ...

# %%
#pubmed_bert
# !python ../code/OpenNRE/example/train_supervised_bert.py \
    --pretrain_path microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext \
    --initial_ckpt ckpt/pubmed_e1_s43_bio_eng.pth.tar \
    --ckpt pubmed_e5_s43_bio_eng_2\
    --pooler entity \
    --metric macro_f1 \
    --train_fil new_results/NEREL_BIOv2.0_train.txt \
    --val_file new_results/NEREL_BIOv2.0_dev.txt \
    --test_file new_results/NEREL_BIOv2.0_test.txt \
    --rel2id_file new_results/rels_NEREL-BIO.txt \
    --batch_size 32 \
    --lr 3e-5 \
    --max_length 128 \
    --max_epoch 5 \
    --seed 43
# Out:
# 2023-04-22 05:19:14,737 - root - INFO - Arguments:
# 2023-04-22 05:19:14,738 - root - INFO -     pretrain_path: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# 2023-04-22 05:19:14,738 - root - INFO -     initial_ckpt: ckpt/pubmed_e1_s43_bio_eng.pth.tar
# 2023-04-22 05:19:14,738 - root - INFO -     ckpt: pubmed_e5_s43_bio_eng_2
# 2023-04-22 05:19:14,738 - root - INFO -     pooler: entity
# 2023-04-22 05:19:14,738 - root - INFO -     only_test: False
# 2023-04-22 05:19:14,738 - root - INFO -     mask_entity: False
# 2023-04-22 05:19:14,738 - root - INFO -     metric: macro_f1
# 2023-04-22 05:19:14,738 - root - INFO -     dataset: none
# 2023-04-22 05:19:14,738 - root - INFO -     train_file: new_results/NEREL_BIOv2.0_train.txt
# 2023-04-22 05:19:14,738 - root - INFO -     val_file: new_results/NEREL_BIOv2.0_dev.txt
# 2023-04-22 05:19:14,738 - root - INFO -     test_file: new_results/NEREL_BIOv2.0_test.txt
# ...

# %%
# --- eng dataset pretraining

# %%
# ClinicalBERT pretraining
# !python ../code/OpenNRE/example/train_supervised_bert.py \
    --pretrain_path emilyalsentzer/Bio_ClinicalBERT \
    --ckpt clinical_e5_s43_bio_eng\
    --pooler entity \
    --metric macro_f1 \
    --train_fil new_results/NEREL_BIO_ENG.txt \
    --val_file new_results/NEREL_BIO_ENG.txt \
    --test_file new_results/NEREL_BIO_ENG.txt \
    --rel2id_file new_results/rels_NEREL-BIO.txt \
    --batch_size 32 \
    --lr 3e-5 \
    --max_length 128 \
    --max_epoch 5 \
    --seed 43
# Out:
# 2023-04-17 22:30:44,835 - root - INFO - Arguments:
# 2023-04-17 22:30:44,836 - root - INFO -     pretrain_path: emilyalsentzer/Bio_ClinicalBERT
# 2023-04-17 22:30:44,836 - root - INFO -     ckpt: clinical_e5_s43_bio_eng
# 2023-04-17 22:30:44,836 - root - INFO -     pooler: entity
# 2023-04-17 22:30:44,836 - root - INFO -     only_test: False
# 2023-04-17 22:30:44,836 - root - INFO -     mask_entity: False
# 2023-04-17 22:30:44,836 - root - INFO -     metric: macro_f1
# 2023-04-17 22:30:44,836 - root - INFO -     dataset: none
# 2023-04-17 22:30:44,836 - root - INFO -     train_file: new_results/NEREL_BIO_ENG.txt
# 2023-04-17 22:30:44,836 - root - INFO -     val_file: new_results/NEREL_BIO_ENG.txt
# 2023-04-17 22:30:44,836 - root - INFO -     test_file: new_results/NEREL_BIO_ENG.txt
# 2023-04-17 22:30:44,836 - root - INFO -     rel2id_file: new_results/rels_NEREL-BIO.txt
# 2023-04-17 22:30:44,836 - root - INFO -     batch_size: 32
# ...

# %%
# ClinicalBERT
# !python ../code/OpenNRE/example/train_supervised_bert.py \
    --pretrain_path emilyalsentzer/Bio_ClinicalBERT \
    --initial_ckpt ckpt/clinical_e5_s43_bio_eng.pth.tar \
    --ckpt clinical_e5_s43_bio_eng_2\
    --pooler entity \
    --metric macro_f1 \
    --train_fil new_results/NEREL_BIOv2.0_train.txt \
    --val_file new_results/NEREL_BIOv2.0_dev.txt \
    --test_file new_results/NEREL_BIOv2.0_test.txt \
    --rel2id_file new_results/rels_NEREL-BIO.txt \
    --batch_size 32 \
    --lr 3e-5 \
    --max_length 128 \
    --max_epoch 5 \
    --seed 43
# Out:
# 2023-04-19 04:00:03,098 - root - INFO - Arguments:
# 2023-04-19 04:00:03,098 - root - INFO -     pretrain_path: emilyalsentzer/Bio_ClinicalBERT
# 2023-04-19 04:00:03,098 - root - INFO -     initial_ckpt: ckpt/clinical_e5_s43_bio_eng.pth.tar
# 2023-04-19 04:00:03,098 - root - INFO -     ckpt: clinical_e5_s43_bio_eng_2
# 2023-04-19 04:00:03,098 - root - INFO -     pooler: entity
# 2023-04-19 04:00:03,098 - root - INFO -     only_test: False
# 2023-04-19 04:00:03,098 - root - INFO -     mask_entity: False
# 2023-04-19 04:00:03,098 - root - INFO -     metric: macro_f1
# 2023-04-19 04:00:03,098 - root - INFO -     dataset: none
# 2023-04-19 04:00:03,098 - root - INFO -     train_file: new_results/NEREL_BIOv2.0_train.txt
# 2023-04-19 04:00:03,098 - root - INFO -     val_file: new_results/NEREL_BIOv2.0_dev.txt
# 2023-04-19 04:00:03,098 - root - INFO -     test_file: new_results/NEREL_BIOv2.0_test.txt
# 2023-04-19 04:00:03,098 - root - INFO -     rel2id_file: new_results/rels_NEREL-BIO.txt
# ...

# %%
#pubmedbert continual pretraining
# !python ../code/OpenNRE/example/train_supervised_bert.py \
    --pretrain_path microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext \
    --ckpt pubmed_e5_s43_bio_eng\
    --pooler entity \
    --metric macro_f1 \
    --train_fil new_results/NEREL_BIO_ENG.txt \
    --val_file new_results/NEREL_BIO_ENG.txt \
    --test_file new_results/NEREL_BIO_ENG.txt \
    --rel2id_file new_results/rels_NEREL-BIO.txt \
    --batch_size 32 \
    --lr 3e-5 \
    --max_length 128 \
    --max_epoch 5 \
    --seed 43
# Out:
# 2023-04-17 23:04:12,538 - root - INFO - Arguments:
# 2023-04-17 23:04:12,538 - root - INFO -     pretrain_path: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# 2023-04-17 23:04:12,538 - root - INFO -     ckpt: pubmed_e5_s43_bio_eng
# 2023-04-17 23:04:12,538 - root - INFO -     pooler: entity
# 2023-04-17 23:04:12,538 - root - INFO -     only_test: False
# 2023-04-17 23:04:12,538 - root - INFO -     mask_entity: False
# 2023-04-17 23:04:12,538 - root - INFO -     metric: macro_f1
# 2023-04-17 23:04:12,538 - root - INFO -     dataset: none
# 2023-04-17 23:04:12,538 - root - INFO -     train_file: new_results/NEREL_BIO_ENG.txt
# 2023-04-17 23:04:12,538 - root - INFO -     val_file: new_results/NEREL_BIO_ENG.txt
# 2023-04-17 23:04:12,538 - root - INFO -     test_file: new_results/NEREL_BIO_ENG.txt
# 2023-04-17 23:04:12,538 - root - INFO -     rel2id_file: new_results/rels_NEREL-BIO.txt
# 2023-04-17 23:04:12,538 - root - INFO -     batch_size: 32
# ...

# %%
# pubmed_bert pretrained
# !python ../code/OpenNRE/example/train_supervised_bert.py \
    --pretrain_path microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext \
    --initial_ckpt ckpt/pubmed_e5_s43_bio_eng.pth.tar \
    --ckpt pubmed_e5_s43_bio_eng_2\
    --pooler entity \
    --metric macro_f1 \
    --train_fil new_results/NEREL_BIOv2.0_train.txt \
    --val_file new_results/NEREL_BIOv2.0_dev.txt \
    --test_file new_results/NEREL_BIOv2.0_test.txt \
    --rel2id_file new_results/rels_NEREL-BIO.txt \
    --batch_size 32 \
    --lr 3e-5 \
    --max_length 128 \
    --max_epoch 5 \
    --seed 43
# Out:
# 2023-04-19 07:07:58,027 - root - INFO - Arguments:
# 2023-04-19 07:07:58,027 - root - INFO -     pretrain_path: microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext
# 2023-04-19 07:07:58,027 - root - INFO -     initial_ckpt: ckpt/pubmed_e5_s43_bio_eng.pth.tar
# 2023-04-19 07:07:58,027 - root - INFO -     ckpt: pubmed_e5_s43_bio_eng_2
# 2023-04-19 07:07:58,027 - root - INFO -     pooler: entity
# 2023-04-19 07:07:58,027 - root - INFO -     only_test: False
# 2023-04-19 07:07:58,027 - root - INFO -     mask_entity: False
# 2023-04-19 07:07:58,027 - root - INFO -     metric: macro_f1
# 2023-04-19 07:07:58,027 - root - INFO -     dataset: none
# 2023-04-19 07:07:58,027 - root - INFO -     train_file: new_results/NEREL_BIOv2.0_train.txt
# 2023-04-19 07:07:58,027 - root - INFO -     val_file: new_results/NEREL_BIOv2.0_dev.txt
# 2023-04-19 07:07:58,027 - root - INFO -     test_file: new_results/NEREL_BIOv2.0_test.txt
# ...
